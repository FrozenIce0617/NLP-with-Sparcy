# %% [markdown]
# ## Task 1
#
# ### Split sentences in the document
# First, import spacy module and load the model.
# For split sentences, create the custom pipe and add it to nlp.

# %%
import spacy
import pickle
activated = spacy.prefer_gpu()
nlp = spacy.load('en_core_web_lg')

# %%
# Custom pipe for seperate sentences from the document
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text in ['\n', '\n\n']:
            doc[token.i+1].is_sent_start = True
    return doc
nlp.add_pipe(set_custom_boundaries, before="parser")

# %%
resume = nlp(open("Sample/Roles.txt", mode = 'r').read())
for i, sent in enumerate(resume.sents):
    print(i, sent.text)
# Out:
# 0 Roles
#
# 1 Role 1
#
# 2 Understand customer needs and develop high-quality presentations, proposals and software demonstrations that speak to these needs – building a consensus for change on a multi-stakeholder basis
#
# 3 Work with the Enterprise sales team to build, manage and maintain customer relationships
#
# 4 Provide pre-sales technical assistance to members of the sales team to ensure proper technical and business fit
#
# 5 Work with marketing on new product development
#
# 6 Present professional and personalised demos
#
# 7 Need to ensure prospective customers are aligned technically with the sales process
#
# 8 Need to understand and demonstrate the solution and how to integrate to other business systems
#
# 9 Role 2
#
# 10 Must Have:
#
#
# 11 Experience shaping the BI strategy from C-Level to Technical developers.
#
# 12 Extensive delivery of platform within a Business Intelligence and Analytics function.
#
# 13 Communication with stakeholders on all levels.
#
# 14 Understanding and experience within KPIs, identifying data sources, building a visualization map and dashboarding.
#
# 15 Led and built a Business Intelligence function and team.
#
# 16 Background within Utilities, Energy, Oil & Gas.
#
# 17 Role 3
#
# 18 Key Responsibilities
#
#
# 19 Lead customers in the creation of new digital solutions which foster their competitive advantage
#
# 20 Enhance and build digital transformation roadmaps
#
# 21 Link digital capabilities to our clients business strategy
#
# 22 Develop C-suite and line-of-business relationships within the customer organization
#
# 23 Define, guide and implement innovation programs – governance, portfolio mix and business fit
#
# 24 Establish the use of cloud services as a means to drive innovation
#
# 25 Collaborate with other AWS specialist teams to drive and shape solutions to accelerate our customer’s business outcomes
#
# 26 Basic Qualifications
#
#
# 27 Experience with a major consulting firm or experience in a corporate role delivering strategy and operations projects with an emphasis in business transformation at the intersection of new operating models and new digital technologies.
#
# 28 Experience in two or more of the following transformation practice areas: ERP (business process architecture and solution implementation), business case and use case development, financial modelling, BI and Analytics strategy and implementation, complex program management, enterprise business / process / IT architectures, executive agenda items and metrics.
#
# 29 Broad understanding of how businesses operate and compete and an understanding of the relationship between major functional areas of the product-centric enterprise (design, plan, procure, manufacture, distribute, service).
#
# 30 Ability to analyse financial and operational data and synthesize findings in common business language.
#
# 31 Experience in using Design Thinking Principles to structure a customer’s thinking and flush out innovative concepts.
#
# 32 Deep understanding of change management practices, particularly stakeholder analysis, workforce readiness and leadership communications.
#
# 33 Strong background in one of the following methodologies: Sigma, Agile/SCRUM, SAFe
#
# 34 Understanding of modern cloud delivery models (Public, Private and Hybrid).
#
# 35 Great business writing and presentation skills.
#
# 36 Excellent communication skills in English
#
# 37 This is a customer facing role.
# 38 You will be required to travel to client locations to deliver professional services as needed
#
# 39 Preferred Qualifications
#
#
# 40 Broad understanding of enterprise systems in large organizations and trends in cloud applications, system integration, and mobile technologies.
#
# 41 Excellent program management skills including developing project plans, resourcing and budgeting projects, and managing a disciplined execution methodology with both internal (direct) and external (indirect) team members.
#
# 42 Experience implementing one or more enterprise solutions on premise and/or in the cloud: ERP, PLM, IoT / Connected Products or Operations, Supply Chain functions as specified above.
#
# 43 Passion for helping customers transform using cloud technologies.

# %% [markdown]
# ### Split phrases from the sentence
#
# Splite phrases from the sentence base on the spacy dependency tree. The algorithm is below:
#
# 1. Find the "VERB" (with part-of-speech)
# 2. Find the verb phrase by the syntactic dependency relation.
# 3. Separate the conjunctions.
# 4. Normalize the sentence.
#
# An example and the dependency tree is shown below. Read the file, split phrases from the document and save as the pickle.

# %%
# Split VP phrases from the sentence
def split_VP_phrases(doc):
    print("Base ===== ", doc.text)
    res = []
    root = doc[:].root
    
    def check_conj(rt):
        for token in rt.rights:
            if token.dep_ not in ['cc', 'conj', 'punct']:
                return False
            if token.dep_ == 'conj':
                break
        return True
    
    def split(rt):   
        if rt.pos_ == 'PUNCT' or rt.pos_ == 'CCONJ' or rt.pos_ == 'SYM':
            return []
        ret = ['']
        if not (rt.pos_ == 'VERB' and rt.dep_ not in ['xcomp', 'ccomp']):
            for token in rt.lefts:
                left_ret = split(token)
                if len(left_ret) == 0:
                    continue
                ret_ = [x + y + " " for x in ret for y in left_ret]
                ret = ret_
        
        ret_ = [x + rt.text for x in ret]
        ret = []
     
        flag = False
        for token in rt.rights:
            right_ret = split(token)
           
            if len(right_ret) == 0:
                continue
            
            if token.dep_ == 'conj' and rt.pos_ == token.pos_ and check_conj(rt):
               
                if not flag:
                    for sent in right_ret:
                      
                        right = doc[token.left_edge.i : token.i+1].text
                        if right in sent:
                            ret.extend([sent.replace(right, x) for x in ret_])
                    flag = True
                if token.pos_ != 'VERB':
                    ret.extend(right_ret)
                ret_ = ret
               
            else:
                ret = [x + " " + y for x in ret_ for y in right_ret]
                ret_ = ret
        ret = ret_
      
        if rt.pos_ == 'VERB' and rt.dep_ not in ['xcomp', 'ccomp']:
            res.extend(ret)
            if rt.dep_ == 'conj' and rt.head.pos_ == 'VERB' and check_conj(rt.head):
                return ret
            else:
                return []
        else:
            if rt.i == root.i:
                res.extend(ret)
            return ret
        
    split(root)
    
    # Normalize the sentence
    res_ = []
    for sent in res:
        sent = nlp(sent)
        if len(sent) < 2:
            continue    
        res_.append(sent.text.replace(sent[0].text, sent[0].lemma_).strip())
    print('\n'.join(res_))
    return res_
      
ex = nlp("Understand customer needs and develop high-quality presentations, proposals and software demonstrations that speak to these needs - building a consensus for change on a multi-stakeholder basis")
from spacy import displacy
displacy.render(ex, style = "dep", jupyter = True)
ret = split_VP_phrases(ex)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="920-0" class="displacy" width="4775" height="574.5" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Understand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">customer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">needs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">develop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">high-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">quality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">presentations,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">proposals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">software</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">demonstrations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">speak</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">needs -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">building</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">consensus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">change</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">multi-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">stakeholder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">basis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-920-0-0" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-920-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-920-0-1" stroke-width="2px" d="M70,439.5 C70,264.5 385.0,264.5 385.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-920-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,441.5 L393.0,429.5 377.0,429.5" fill="currentColor"/>
# </g>
#
# <g cl
# Base =====  Understand customer needs and develop high-quality presentations, proposals and software demonstrations that speak to these needs - building a consensus for change on a multi-stakeholder basis
# speak to a consensus for change on a multi stakeholder basis
# develop high quality presentations
# develop proposals
# develop software demonstrations
# understand customer needs

# %%
phrases = []
role = nlp(open("Sample/Roles.txt", mode = 'r').read())
for sent in resume.sents:
    phrases.extend(split_VP_phrases(nlp(sent.text.strip())))

# Save the phrases
with open('role_phrases.pickle', 'wb') as f:
    pickle.dump(phrases, f)
# Out:
# Base =====  Roles
#
# Base =====  Role 1
# role 1
# Base =====  Understand customer needs and develop high-quality presentations, proposals and software demonstrations that speak to these needs – building a consensus for change on a multi-stakeholder basis
# speak to these needs –
# develop high quality presentations
# develop proposals
# develop software demonstrations
# build a consensus for change on a multi stakeholder basis
# understand customer needs
# Base =====  Work with the Enterprise sales team to build, manage and maintain customer relationships
# maintain customer relationships
# manage customer relationships
# build customer relationships
# work with the Enterprise sales team
# Base =====  Provide pre-sales technical assistance to members of the sales team to ensure proper technical and business fit
# ensure proper technical business fit
# provide sales technical assistance to members of the sales team
# Base =====  Work with marketing on new product development
# work with marketing on new product development
# Base =====  Present professional and personalised demos
# professional demos
# Base =====  Need to ensure prospective customers are aligned technically with the sales process
# need to ensure prospective customers aligned technically with the sales process
# Base =====  Need to understand and demonstrate the solution and how to integrate to other business systems
# integrate to other business systems
# demonstrate the solution
# need to understand the solution
# Base =====  Role 2
# role 2
# Base =====  Must Have:
#
# Base =====  Experience shaping the BI strategy from C-Level to Technical developers.
# shape the BI strategy from C Level to Technical developers
# Base =====  Extensive delivery of platform within a Business Intelligence and Analytics function.
# extensive delivery of platform within a Business Intelligence function
# extensive delivery of platform within a Analytics function
# Base =====  Communication with stakeholders on all levels.
# communication with stakeholders on all levels
# Base =====  Understanding and experience within KPIs, identifying data sources, building a visualization map and dashboarding.
# build a visualization map
# build dashboarding
# identify data sources
# understand experience within KPIs
# Base =====  Led and built a Business Intelligence function and team.
# build a Business Intelligence function
# build team
# Base =====  Background within Utilities, Energy, Oil & Gas.
# background within Utilities
# background within Energy
# background within Oil
# background within Gas
# Base =====  Role 3
# role 3
# Base =====  Key Responsibilities
# key Responsibilities
# Base =====  Lead customers in the creation of new digital solutions which foster their competitive advantage
# foster their competitive advantage
# lead customers in the creation of new digital solutions
# Base =====  Enhance and build digital transformation roadmaps
# build digital transformation roadmaps
# enhance digital transformation roadmaps
# Base =====  Link digital capabilities to our clients business strategy
# digital capabilities to our clients business strategy
# Base =====  Develop C-suite and line-of-business relationships within the customer organization
# develop C suite of business relationships within the customer organization
# develop line of business relationships within the customer organization
# Base =====  Define, guide and implement innovation programs – governance, portfolio mix and business fit
# implement innovation programs – governance
# implement portfolio mix
# implement business fit
# guide innovation programs – governance
# guide portfolio mix
# guide business fit
# define innovation programs – governance
# define portfolio mix
# define business fit
# Base =====  Establish the use of cloud services as a means to drive innovation
# drive innovation
# establish the use of cloud services as a means
# Base =====  Collaborate with other AWS specialist teams to drive and shape solutions to accelerate our customer’s business outcomes
# drive shape
# accelerate our customer ’s business outcomes
# collaborate with other AWS specialist teams solutions
# Base =====  Basic Qualifications
# basic Qualifications
# Base =====  Experience with a major consulting firm or experience in a corporate role delivering strategy and operations projects with an emphasis in business transformation at the intersection of new operating models and new digital technologies.
# deliver strategy projects with an emphasis in business transformation at the intersection of new operating models
# deliver strategy projects with an emphasis in business transformation at the intersection of new digital technologies
# deliver operations projects with an emphasis in business transformation at the intersection of new operating models
# deliver operations projects with an emphasis in business transformation at the intersection of new digital technologies
# experience with a major consulting firm in a corporate role
# experience with experience in a corporate role
# Base =====  Experience in two or more of the following transformation practice areas: ERP (business process architecture and solution implementation), business case and use case development, financial modelling, BI and Analytics strategy and implementation, complex program management, enterprise business / process / IT architectures, executive agenda items and metrics.
# experience in two more of the transformation practice areas ERP business case BI strategy
# experience in two more of the transformation practice areas ERP business case Analytics strategy
# experience in two more of the transformation practice areas ERP business case implementation
# experience in two more of the transformation practice areas ERP business case enterprise business process IT architectures
# experience in two more of the transformation practice areas ERP business case executive agenda items
# experience in two more of the transformation practice areas ERP business case metrics
# experience in two more of the transformation practice areas ERP use BI strategy
# experience in two more of the transformation practice areas ERP use Analytics strategy
# experience in two more of the transformation practice areas ERP use implementation
# experience in two more of the transformation practice areas ERP use enterprise business process IT architectures
# experience in two more of the transformation practice areas ERP use executive agenda items
# experience in two more of the transformation practice areas ERP use metrics
# experience in two more of the transformation practice areas business process architecture business case BI strategy
# experience in two more of the transformation practice areas business process architecture business case Analytics strategy
# experience in two more of the transformation practice areas business process architecture business case implementation
# experience in two more of the transformation practice areas business process architecture business case enterprise business process IT architectures
# experience in two more of the transformation practice areas business process architecture business case executive agenda items
# experience in two more of the transformation practice areas business process architecture business case metrics
# experience in two more of the transformation practice areas business process architecture use BI strategy
# experience in two more of the transformation practice areas business process architecture use Analytics strategy
# experience in two more of the transformation practice areas business process architecture use implementation
# experience in two more of the transformation practice areas business process architecture use enterprise business process IT architectures
# experience in two more of the transformation practice areas business process architecture use executive agenda items
# experience in two more of the transformation practice areas business process architecture use metrics
# experience in two more of the transformation practice areas solution business case BI strategy
# experience in two more of the transformation practice areas solution business case Analytics strategy
# experience in two more of the transformation practice areas solution business case implementation
# experience in two more of the transformation practice areas solution business case enterprise business process IT architectures
# experience in two more of the transformation practice areas solution business case executive agenda items
# experience in two more of the transformation practice areas solution business case metrics
# experience in two more of the transformation practice areas solution use BI strategy
# experience in two more of the transformation practice areas solution use Analytics strategy
# experience in two more of the transformation practice areas solution use implementation
# experience in two more of the transformation practice areas solution use enterprise business process IT architectures
# experience in two more of the transformation practice areas solution use executive agenda items
# experience in two more of the transformation practice areas solution use metrics
# experience in two more of the transformation practice areas implementation business case BI strategy
# experience in two more of the transformation practice areas implementation business case Analytics strategy
# experience in two more of the transformation practice areas implementation business case implementation
# experience in two more of the transformation practice areas implementation business case enterprise business process IT architectures
# experience in two more of the transformation practice areas implementation business case executive agenda items
# experience in two more of the transformation practice areas implementation business case metrics
# experience in two more of the transformation practice areas implementation use BI strategy
# experience in two more of the transformation practice areas implementation use Analytics strategy
# experience in two more of the transformation practice areas implementation use implementation
# experience in two more of the transformation practice areas implementation use enterprise business process IT architectures
# experience in two more of the transformation practice areas implementation use executive agenda items
# experience in two more of the transformation practice areas implementation use metrics
# Base =====  Broad understanding of how businesses operate and compete and an understanding of the relationship between major functional areas of the product-centric enterprise (design, plan, procure, manufacture, distribute, service).
# distribute service
# manufacture service
# procure service
# broad understanding of an understanding of the relationship between major functional areas of the product centric enterprise design
# broad understanding of an understanding of the relationship between major functional areas of the product centric enterprise plan
# Base =====  Ability to analyse financial and operational data and synthesize findings in common business language.
# synthesize findings in common business language
# analyse financial data
# analyse operational data
# Base =====  Experience in using Design Thinking Principles to structure a customer’s thinking and flush out innovative concepts.
# flush out innovative concepts
# use Principles to structure a customer ’s thinking
# experience in
# Base =====  Deep understanding of change management practices, particularly stakeholder analysis, workforce readiness and leadership communications.
# deep understanding of change management practices particularly stakeholder analysis
# deep understanding of change management practices workforce readiness
# deep understanding of change management practices leadership communications
# Base =====  Strong background in one of the following methodologies: Sigma, Agile/SCRUM, SAFe
# strong background in one of the methodologies Sigma Agile SCRUM SAFe
# Base =====  Understanding of modern cloud delivery models (Public, Private and Hybrid).
# understand of modern cloud delivery models Public Hybrid
# understand of modern cloud delivery models Private Hybrid
# Base =====  Great business writing and presentation skills.
# great business writing skills
# presentation skills
# Base =====  Excellent communication skills in English
# excellent communication skills in English
# Base =====  This is a customer facing role.
# face role
# be a customer
# Base =====  You will be required to travel to client locations to deliver professional services as needed
# deliver professional services
# require to travel to client locations
# Base =====  Preferred Qualifications
# preferred Qualifications
# Base =====  Broad understanding of enterprise systems in large organizations and trends in cloud applications, system integration, and mobile technologies.
# broad understanding of enterprise systems in large organizations in cloud applications
# broad understanding of enterprise systems in large organizations in system integration
# broad understanding of enterprise systems in large organizations in mobile technologies
# broad understanding of enterprise systems in trends in cloud applications
# broad understanding of enterprise systems in trends in system integration
# broad understanding of enterprise systems in trends in mobile technologies
# Base =====  Excellent program management skills including developing project plans, resourcing and budgeting projects, and managing a disciplined execution methodology with both internal (direct) and external (indirect) team members.
# manage a execution methodology with both internal direct indirect team members
# manage a execution methodology with external indirect team members
# develop project plans
# develop resourcing
# develop budgeting
# develop projects
# excellent program management skills
# Base =====  Experience implementing one or more enterprise solutions on premise and/or in the cloud: ERP, PLM, IoT / Connected Products or Operations, Supply Chain functions as specified above.
# implement one more enterprise solutions on premise
# specify above
# experience ERP PLM IoT Connected Products Supply Chain functions
# experience ERP PLM IoT Operations Supply Chain functions
# Base =====  Passion for helping customers transform using cloud technologies.
# help customers transform using cloud technologies
# passion for

# %%
phrases = []
resume = nlp(open("Sample/Resume.txt", mode = 'r').read())
for sent in resume.sents:
    phrases.extend(split_VP_phrases(nlp(sent.text.strip())))

with open('resume_phrases.pickle', 'wb') as f:
    pickle.dump(phrases, f)
# Out:
# Base =====  Resume
#
# Base =====  Consulting customer lead, Company 1 – San Jose (CR), Toronto (CA) January 2018 - May 2018
# consulting customer lead Company 1 – San Jose CR Toronto CA January 2018 May 2018
# Base =====  Identified processes automation portfolio totalling 50 FTE for 2019 and long-term potential of 200+ FTE
# total 50 FTE for 2019 long term potential of 200 FTE
# identify processes automation portfolio
# Base =====  Oversaw agile delivery of four opportunities, working with offshore technical teams and business
# work with offshore technical teams
# work with business
# agile delivery of four opportunities
# Base =====  Architected reusable framework to integrate into SAP saving significant cost and reducing timelines
# reduce timelines
# save significant cost
# integrate into
# reusable framework
# Base =====  Developed demand generation and assessment approach for Smart Automation CoE
# demand generation approach for Smart Automation CoE
# assessment approach for Smart Automation CoE
# Base =====  Programme lead, Company 2 – Johannesburg (SA) January 2017 - December 2017
# programme lead
# Base =====  Educated and coached more than 100 business participants that delivered 150+ automation solutions leading to significant business benefits and cost savings
# lead to significant business benefits
# lead to cost savings
# deliver 150 automation solutions
# coach more than 100 business participants
# educate more than 100 business participants
# Base =====  Increased business impact by more than 20% by focusing on outcomes and growing automation opportunities
# focus on automation opportunities
# business impact by more than 20 % by
# Base =====  Solution lead and architect, Company 3 – Farnborough (UK), Atyrau (KZ) January 2016 - December 2016
# solution lead Company 3 – Farnborough UK Atyrau KZ January 2016 December 2016
# architect Company 3 – Farnborough UK Atyrau KZ January 2016 December 2016
# Base =====  Went through a complex architecture and governance process to establish the automation solution based on UiPath with IT and internal controls
# base on UiPath with IT internal controls
# establish the automation solution
# go through a complex architecture process
# go through a complex governance process
# Base =====  Mapped and optimised process and delivered the automation solution
# deliver the automation solution
# map optimised process
# Base =====  Project and solution lead, Company 4 – Newcastle (UK), San Jose (CR), Manila (PH)
# project lead
# solution lead
# Base =====  January 2015 - December 2015
# january 2015 December 2015
# Base =====  Turned project around after initial process assessment did not identify sufficient benefits
# identify sufficient benefits
# Base =====  Successfully delivered savings potential of 100 FTE across individual projects with a combination of process improvement and automation
# deliver savings potential of 100 FTE across individual projects with a combination of process improvement
# deliver savings potential of 100 FTE across individual projects with a combination of automation
# Base =====  Delivered an automation ecosystem based on SAP, BluePrism, ServiceNow, Knime and Spotfire and built capability with the customer to dramatically reduce time spent in finance processes
# base on SAP
# base on BluePrism
# base on ServiceNow
# base on Knime
# base on Spotfire
# spend in finance processes
# reduce time
# deliver an automation ecosystem capability with the customer
# Base =====  Solution lead and HR workstream lead, Company 5 – Coventry (UK) January 2014 - December 2014
# solution lead December 2014
# hr December 2014
# workstream lead December 2014
# Base =====  Turned project around given a very demanding customer
# give a very demanding customer
# project around
# Base =====  Delivered a Proof of Concept (PoC) to demonstrate automation impact on selected processes
# demonstrate automation impact on processes
# deliver a Proof of Concept PoC
# Base =====  Business case showed an RoI of 100% with an initial 9-month implementation phase
# show an RoI of 100 % with an initial 9-month implementation phase
# Base =====  Project moved into implementation based on the business case
# base on the business case
# move into implementation
# Base =====  Solution lead, Company 6 –
# solution lead Company 6 –
# Base =====  Budapest (HU), Manila (PH),
# budapest HU Manila PH
# Base =====  Bangalore (IN) January 2013 - December 2013
# bangalore IN January 2013 December 2013
# Base =====  Defined a scalable architecture for chosen RPA platform
# define a scalable architecture for RPA platform
# Base =====  Delivered savings of more than 60 FTE and moved into second implementation wave
# move into second implementation wave
# saving of more than 60 FTE
# Base =====  Project lead, Company 7 – Budapest (HU) January 2012 - December 2012
# project lead Budapest HU January 2012 December 2012
# Base =====  Delivered a Proof of Value (PoV) to demonstrate RPA / data automation impact on selected processes
# demonstrate RPA data automation impact on processes
# deliver a Proof of Value PoV
# Base =====  Business case demonstrated savings of 25-35% and in some areas, up to 75%, supported by PoV
# support by PoV
# demonstrate savings of 25 35 % in some areas up to 75 %
# Base =====  Project moved into implementation based on the business case
# base on the business case
# move into implementation
